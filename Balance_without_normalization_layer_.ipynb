# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.patches as mpatches
import time

import collections
from sklearn.model_selection import train_test_split

from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, accuracy_score, classification_report
from collections import Counter
import warnings
warnings.filterwarnings("ignore")

# %%
# all the known virus miRNAs are used as positive examples
features_virus_mirnas = pd.read_csv('/content/drive/MyDrive/features_virus_miRNAs.csv')

# The negative set is composed of a random set of hsa hairpin-like sequences 
features_unlabeled_hairpins = pd.read_csv('/content/drive/MyDrive/features_unlabeled_hairpins.csv') # Hairpins from hsa genome

# %%
features_virus_mirnas.drop('sequence_names', inplace=True, axis=1)

# %%
features_virus_mirnas['class'] = 1

# %%
features_unlabeled_hairpins.drop('sequence_names', inplace=True, axis=1)

# %%
features_unlabeled_hairpins['class'] = 0

# %%
da = [features_virus_mirnas, features_unlabeled_hairpins]

# %%
df = pd.concat(da)
df.head()
# Out:
#     nt_proportion0   nt_proportion1   nt_proportion2   nt_proportion3  \
# 0         0.292308         0.169231         0.200000         0.338462
# 1         0.276923         0.215385         0.230769         0.276923
# 2         0.242424         0.287879         0.227273         0.242424
# 3         0.200000         0.257143         0.300000         0.242857
# 4         0.258065         0.193548         0.225806         0.322581
#
#     dinucleotide_proportion0   dinucleotide_proportion1  \
# 0                   0.109375                   0.015625
# 1                   0.125000                   0.078125
# 2                   0.061538                   0.061538
# 3                   0.028986                   0.057971
# 4                   0.098361                   0.016393
#
#     dinucleotide_proportion2   dinucleotide_proportion3  \
# 0                   0.078125                   0.093750
# 1                   0.046875                   0.031250
# 2                   0.061538                   0.046154
# 3                   0.057971                   0.057971
# 4                   0.049180                   0.081967
#
#     dinucleotide_proportion4   dinucleotide_proportion5  ...    efe  \
# 0                   0.062500                   0.031250  ... -27.28
# 1                   0.078125                   0.000000  ... -23.95
# 2                   0.061538                   0.138462  ... -27.02
# 3                   0.057971                   0.072464  ... -32.11
# 4                   0.049180                   0.049180  ... -26.28
#
#     ensemble_frequency   diversity   mfe_efe_difference        dQ        dG  \
# 0             0.457857        1.67             0.007385  0.066635 -0.412308
# 1             0.154283        5.77             0.017692  0.228730 -0.350769
# 2             0.426696        2.62             0.007879  0.107199 -0.401515
# 3             0.101080        6.03             0.020143  0.214866 -0.438571
# 4             0.639769        0.94             0.004516  0.040681 -0.419355
#
#       mfei1     mfei2     mfei4  class
# 0 -1.116667 -0.137436 -1.072000      1
# 1 -0.786207 -0.116923 -1.036364      1
# 2 -0.779412 -0.100379 -1.204545      1
# 3 -0.787179 -0.146190 -1.228000      1
# 4 -1.000000 -0.139785 -1.238095      1
#
# [5 rows x 74 columns]

# %%
df.fillna(value=0, inplace = True)

# %%
df.isnull().sum().max()
# Out:
# 0

# %%
df = df.sample(frac=1)

positive_df = df.loc[df['class'] == 1]
negative_df = df.loc[df['class'] == 0][:569]

normal_distributed_df = pd.concat([positive_df, negative_df])

new_df = normal_distributed_df.sample(frac=1, random_state=42)

new_df.head()
# Out:
#          nt_proportion0   nt_proportion1   nt_proportion2   nt_proportion3  \
# 270609         0.393000         0.214000         0.155000         0.238000
# 838379         0.239000         0.193000         0.229000         0.339000
# 514            0.263158         0.140351         0.192982         0.403509
# 327167         0.264000         0.236000         0.208000         0.292000
# 244            0.172414         0.206897         0.310345         0.310345
#
#          dinucleotide_proportion0   dinucleotide_proportion1  \
# 270609                   0.169000                   0.072000
# 838379                   0.028000                   0.046000
# 514                      0.107143                   0.035714
# 327167                   0.085000                   0.056000
# 244                      0.052632                   0.035088
#
#          dinucleotide_proportion2   dinucleotide_proportion3  \
# 270609                   0.096000                   0.060000
# 838379                   0.083000                   0.083000
# 514                      0.000000                   0.125000
# 327167                   0.056000                   0.070000
# 244                      0.052632                   0.035088
#
#          dinucleotide_proportion4   dinucleotide_proportion5  ...    efe  \
# 270609                   0.133000                   0.012000  ... -15.70
# 838379                   0.046000                   0.056000  ... -31.65
# 514                      0.071429                   0.017857  ... -22.63
# 327167                   0.042000                   0.056000  ... -17.34
# 244                      0.070175                   0.035088  ... -26.37
#
#          ensemble_frequency   diversity   mfe_efe_difference        dQ  \
# 270609             0.104000       10.85             0.017000  0.373000
# 838379             0.132000        7.76             0.011000  0.204000
# 514                0.583674        1.20             0.005789  0.045986
# 327167             0.096000       13.68             0.020000  0.558000
# 244                0.150014        3.14             0.020172  0.141012
#
#               dG     mfei1     mfei2   mfei4  class
# 270609 -0.170000 -0.461000 -0.057000  -0.681      0
# 838379 -0.279000 -0.661000 -0.070000  -0.822      0
# 514    -0.391228 -1.173684 -0.195614  -1.115      1
# 327167 -0.221000 -0.497000 -0.074000  -0.691      0
# 244    -0.434483 -0.840000 -0.144828  -1.200      1
#
# [5 rows x 74 columns]

# %%
X = new_df.iloc[:,:-1]
y = new_df.iloc[:,73]

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder
en = LabelEncoder()
en_y = en.fit_transform(y)

F_y = tf.keras.utils.to_categorical(en_y)

# %%
seed = 7
np.random.seed(seed)
x_train,x_test,y_train,y_test = train_test_split(X,F_y,test_size=0.20,random_state=seed,stratify=en_y,shuffle=True)
st = StandardScaler()
st_xtrain = st.fit_transform(x_train)
st_xtest = st.fit_transform(x_test)

# %%
AN = tf.keras.models.Sequential()
AN.add(tf.keras.layers.Dense(1024, input_dim=73, activation=tf.nn.relu))
AN.add(tf.keras.layers.Dense(512, activation=tf.nn.relu))
AN.add(tf.keras.layers.Dense(512, activation=tf.nn.relu))
AN.add(tf.keras.layers.Dense(256, activation=tf.nn.relu))
AN.add(tf.keras.layers.Dense(256, activation=tf.nn.relu))
AN.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))
AN.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))
AN.add(tf.keras.layers.Dense(64, activation=tf.nn.relu))
AN.add(tf.keras.layers.Dense(64, activation=tf.nn.relu))
AN.add(tf.keras.layers.Dense(32, activation=tf.nn.relu))
AN.add(tf.keras.layers.Dense(16, activation=tf.nn.relu))
AN.add(tf.keras.layers.Dense(16, activation=tf.nn.relu))
AN.add(tf.keras.layers.Dense(2, activation=tf.nn.sigmoid))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %%
AN.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

history = AN.fit(st_xtrain, y_train,validation_data=(st_xtest,y_test),epochs=90, batch_size=20)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 910 samples, validate on 228 samples
# Epoch 1/90
# 910/910 [==============================] - 1s 947us/sample - loss: 0.3698 - acc: 0.8544 - val_loss: 0.3251 - val_acc: 0.8947
# Epoch 2/90
# 910/910 [==============================] - 1s 710us/sample - loss: 0.1571 - acc: 0.9374 - val_loss: 0.3771 - val_acc: 0.8860
# Epoch 3/90
# 910/910 [==============================] - 1s 713us/sample - loss: 0.1199 - acc: 0.9610 - val_loss: 0.4340 - val_acc: 0.9123
# Epoch 43/90
# 910/910 [==============================] - 1s 745us/sample - loss: 6.0506e-08 - acc: 1.0000 - val_loss: 5.1747 - val_acc: 0.9211
# Epoch 44/90
# 910/910 [==============================] - 1s 720us/sample - loss: 5.5866e-08 - acc: 1.0000 - val_loss: 5.2130 - val_acc: 0.9211
# Epoch 45/90
# 910/910 [==============================] - 1s 720us/sample - loss: 5.2201e-08 - acc: 1.0000 - val_loss: 5.2491 - val_acc: 0.9211
# Epoch 46/90
# 910/910 [==============================] - 1s 716us/sample - loss: 4.7816e-08 - acc: 1.0000 - val_loss: 5.2758 - val_acc: 0.9211
# Epoch 47/90
# 910/910 [==============================] - 1s 737us/sample - loss: 4.4590e-08 - acc: 1.0000 - val_loss: 5.3017 - val_acc: 0.9211
# Epoch 48/90
# 910/910 [==============================] - 1s 734us/sample - loss: 4.1681e-08 - acc: 1.0000 - val_loss: 5.3352 - val_acc: 0.9211
# Epoch 49/90
# 910/910 [==============================] - 1s 730us/sample - loss: 3.8770e-08 - acc: 1.0000 - val_loss: 5.3594 - val_acc: 0.9211
# Epoch 50/90
# 910/910 [==============================] - 1s 707us/sample - loss: 3.6476e-08 - acc: 1.0000 - val_loss: 5.3893 - val_acc: 0.9211
# Epoch 51/90
# 910/910 [==============================] - 1s 732us/sample - loss: 3.3993e-08 - acc: 1.0000 - val_loss: 5.4122 - val_acc: 0.9211
# Epoch 52/90
# 910/910 [==============================] - 1s 749us/sample - loss: 3.2351e-08 - acc: 1.0000 - val_loss: 5.4409 - val_acc: 0.9211
# Epoch 53/90
# 910/910 [==============================] - 1s 715us/sample - loss: 3.0061e-08 - acc: 1.0000 - val_loss: 5.4643 - val_acc: 0.9211
# Epoch 54/90
# 910/910 [==============================] - 1s 707us/sample - loss: 2.8323e-08 - acc: 1.0000 - val_loss: 5.4871 - val_acc: 0.9211
# Epoch 55/90
# 910/910 [==============================] - 1s 726us/sample - loss: 2.6755e-08 - acc: 1.0000 - val_loss: 5.5124 - val_acc: 0.9211
# Epoch 56/90
# 910/910 [==============================] - 1s 745us/sample - loss: 2.5179e-08 - acc: 1.0000 - val_loss: 5.5365 - val_acc: 0.9211
# Epoch 57/90
# 910/910 [==============================] - 1s 744us/sample - loss: 2.3768e-08 - acc: 1.0000 - val_loss: 5.5594 - val_acc: 0.9211
# Epoch 58/90
# 910/910 [==============================] - 1s 762us/sample - loss: 2.2430e-08 - acc: 1.0000 - val_loss: 5.5766 - val_acc: 0.9211
# Epoch 59/90
# 910/910 [==============================] - 1s 781us/sample - loss: 2.1347e-08 - acc: 1.0000 - val_loss: 5.6026 - val_acc: 0.9211
# Epoch 60/90
# 910/910 [==============================] - 1s 758us/sample - loss: 2.0150e-08 - acc: 1.0000 - val_loss: 5.6276 - val_acc: 0.9211
# Epoch 61/90
# 910/910 [==============================] - 1s 750us/sample - loss: 1.9147e-08 - acc: 1.0000 - val_loss: 5.6516 - val_acc: 0.9211
# Epoch 62/90
# 910/910 [==============================] - 1s 749us/sample - loss: 1.8158e-08 - acc: 1.0000 - val_loss: 5.6728 - val_acc: 0.9211
# Epoch 63/90
# 910/910 [==============================] - 1s 754us/sample - loss: 1.7190e-08 - acc: 1.0000 - val_loss: 5.6869 - val_acc: 0.9211
# Epoch 64/90
# 910/910 [==============================] - 1s 770us/sample - loss: 1.6357e-08 - acc: 1.0000 - val_loss: 5.7129 - val_acc: 0.9211
# Epoch 65/90
# 910/910 [==============================] - 1s 781us/sample - loss: 1.5553e-08 - acc: 1.0000 - val_loss: 5.7354 - val_acc: 0.9211
# Epoch 66/90
# 910/910 [==============================] - 1s 768us/sample - loss: 1.4845e-08 - acc: 1.0000 - val_loss: 5.7556 - val_acc: 0.9211
# Epoch 67/90
# 910/910 [==============================] - 1s 747us/sample - loss: 1.4124e-08 - acc: 1.0000 - val_loss: 5.7753 - val_acc: 0.9211
# Epoch 68/90
# 910/910 [==============================] - 1s 772us/sample - loss: 1.3459e-08 - acc: 1.0000 - val_loss: 5.7954 - val_acc: 0.9211
# Epoch 69/90
# 910/910 [==============================] - 1s 760us/sample - loss: 1.2806e-08 - acc: 1.0000 - val_loss: 5.8125 - val_acc: 0.9211
# Epoch 70/90
# 910/910 [==============================] - 1s 751us/sample - loss: 1.2261e-08 - acc: 1.0000 - val_loss: 5.8338 - val_acc: 0.9211
# Epoch 71/90
# 910/910 [==============================] - 1s 769us/sample - loss: 1.1699e-08 - acc: 1.0000 - val_loss: 5.8514 - val_acc: 0.9211
# Epoch 72/90
# 910/910 [==============================] - 1s 784us/sample - loss: 1.1171e-08 - acc: 1.0000 - val_loss: 5.8645 - val_acc: 0.9211
# Epoch 73/90
# 910/910 [==============================] - 1s 783us/sample - loss: 1.0747e-08 - acc: 1.0000 - val_loss: 5.8885 - val_acc: 0.9211
# Epoch 74/90
# 910/910 [==============================] - 1s 769us/sample - loss: 1.0201e-08 - acc: 1.0000 - val_loss: 5.9073 - val_acc: 0.9211
# Epoch 75/90
# 910/910 [==============================] - 1s 763us/sample - loss: 9.7514e-09 - acc: 1.0000 - val_loss: 5.9254 - val_acc: 0.9211
# Epoch 76/90
# 910/910 [==============================] - 1s 756us/sample - loss: 9.3154e-09 - acc: 1.0000 - val_loss: 5.9421 - val_acc: 0.9211
# Epoch 77/90
# 910/910 [==============================] - 1s 759us/sample - loss: 8.9927e-09 - acc: 1.0000 - val_loss: 5.9624 - val_acc: 0.9211
# Epoch 78/90
# 910/910 [==============================] - 1s 775us/sample - loss: 8.5648e-09 - acc: 1.0000 - val_loss: 5.9806 - val_acc: 0.9211
# Epoch 79/90
# 910/910 [==============================] - 1s 754us/sample - loss: 8.1914e-09 - acc: 1.0000 - val_loss: 5.9964 - val_acc: 0.9211
# Epoch 80/90
# 910/910 [==============================] - 1s 765us/sample - loss: 7.8539e-09 - acc: 1.0000 - val_loss: 6.0156 - val_acc: 0.9211
# Epoch 81/90
# 910/910 [==============================] - 1s 772us/sample - loss: 7.5032e-09 - acc: 1.0000 - val_loss: 6.0307 - val_acc: 0.9211
# Epoch 82/90
# 910/910 [==============================] - 1s 741us/sample - loss: 7.2061e-09 - acc: 1.0000 - val_loss: 6.0477 - val_acc: 0.9211
# Epoch 83/90
# 910/910 [==============================] - 1s 739us/sample - loss: 6.8592e-09 - acc: 1.0000 - val_loss: 6.0704 - val_acc: 0.9211
# Epoch 84/90
# 910/910 [==============================] - 1s 772us/sample - loss: 6.5840e-09 - acc: 1.0000 - val_loss: 6.0875 - val_acc: 0.9211
# Epoch 85/90
# 910/910 [==============================] - 1s 741us/sample - loss: 6.3177e-09 - acc: 1.0000 - val_loss: 6.1008 - val_acc: 0.9211
# Epoch 86/90
# 910/910 [==============================] - 1s 767us/sample - loss: 6.0800e-09 - acc: 1.0000 - val_loss: 6.1149 - val_acc: 0.9211
# Epoch 87/90
# 910/910 [==============================] - 1s 748us/sample - loss: 5.8584e-09 - acc: 1.0000 - val_loss: 6.1314 - val_acc: 0.9211
# Epoch 88/90
# 910/910 [==============================] - 1s 770us/sample - loss: 5.6412e-09 - acc: 1.0000 - val_loss: 6.1498 - val_acc: 0.9211
# Epoch 89/90
# 910/910 [==============================] - 1s 733us/sample - loss: 5.4261e-09 - acc: 1.0000 - val_loss: 6.1625 - val_acc: 0.9211
# Epoch 90/90
# 910/910 [==============================] - 1s 746us/sample - loss: 5.2477e-09 - acc: 1.0000 - val_loss: 6.1828 - val_acc: 0.9211

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Without Normalization Model Accuracy')
plt.ylabel('acuuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Without Normalization Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
ownpredictions = AN.predict(st_xtest)

# %%
from sklearn.metrics import confusion_matrix

ocm=confusion_matrix(y_test.argmax(axis=1),ownpredictions.argmax(axis=1))
plt.title('Without Normalization Model Confusion Matrix')
sns.heatmap(ocm,annot=True,fmt="d")

# %%
from sklearn.metrics import matthews_corrcoef,cohen_kappa_score,hamming_loss
from sklearn import metrics
print("matthews_corrcoef",matthews_corrcoef(y_test.argmax(axis=1), ownpredictions.argmax(axis=1)))
print("cohen_kappa_score",cohen_kappa_score(y_test.argmax(axis=1), ownpredictions.argmax(axis=1)))
print("hamming_loss_score",hamming_loss(y_test.argmax(axis=1), ownpredictions.argmax(axis=1)))
print("Precision_score", metrics.precision_score(y_test.argmax(axis=1), ownpredictions.argmax(axis=1)))
print("Pecall_score",metrics.recall_score(y_test.argmax(axis=1), ownpredictions.argmax(axis=1)))
print("F1_score",metrics.f1_score(y_test.argmax(axis=1), ownpredictions.argmax(axis=1)))
print("Accuracy_score",metrics.accuracy_score(y_test.argmax(axis=1), ownpredictions.argmax(axis=1)))
print("Roc_auc_score",metrics.roc_auc_score(y_test.argmax(axis=1),ownpredictions.argmax(axis=1)))
print("Fbeta_score",metrics.fbeta_score(y_test.argmax(axis=1), ownpredictions.argmax(axis=1), beta=0.5))
print("Fbeta_score",metrics.fbeta_score(y_test.argmax(axis=1), ownpredictions.argmax(axis=1), beta=1))
print("Fbeta_score",metrics.fbeta_score(y_test.argmax(axis=1), ownpredictions.argmax(axis=1), beta=2))
# Out:
# matthews_corrcoef 0.8421052631578947
# cohen_kappa_score 0.8421052631578947
# hamming_loss_score 0.07894736842105263
# Precision_score 0.9210526315789473
# Pecall_score 0.9210526315789473
# F1_score 0.9210526315789473
# Accuracy_score 0.9210526315789473
# Roc_auc_score 0.9210526315789473
# Fbeta_score 0.9210526315789472
# Fbeta_score 0.9210526315789473
# Fbeta_score 0.9210526315789472
